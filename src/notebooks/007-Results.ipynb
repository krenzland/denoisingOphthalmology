# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../results.csv')
df['better_psnr'] = (df['psnr_sr'] > df['psnr_bic'])*1.0
df['better_acc'] = (df['frangi_acc_sr'] > df['frangi_acc_bic'])*1.0

# %%
df.describe()
# Out:
#        upscale_time    psnr_sr   psnr_bic  frangi_acc_sr  frangi_acc_bic  \
# count     80.000000  80.000000  80.000000      80.000000       80.000000
# mean       0.009718  32.824547  33.227886      98.055177       97.554522
# std        0.059170   1.890364   1.868009       0.501039        0.530763
# min        0.002669  29.737831  30.199162      96.362589       95.878894
# 25%        0.003018  31.353443  31.621121      97.818978       97.340056
# 50%        0.003116  32.636592  33.103567      98.129773       97.635774
# 75%        0.003145  34.301538  34.608198      98.378516       97.889896
# max        0.532328  36.929283  36.358766      98.850770       98.243727
#
#        segmentation_acc_hr  segmentation_acc_sr  segmentation_acc_bic  \
# count            80.000000            80.000000             80.000000
# mean             94.257440            94.197316             93.691493
# std               1.345121             1.242073              1.143024
# min              89.493575            89.472360             89.926961
# 25%              93.910929            94.097391             93.662868
# 50%              94.424779            94.443266             93.919414
# 75%              94.953858            94.798991             94.256046
# max              95.975270            95.670687             95.112438
#
#        better_psnr  better_acc
# count    80.000000        80.0
# mean      0.225000         1.0
# std       0.420217         0.0
# min       0.000000         1.0
# 25%       0.000000         1.0
# 50%       0.000000         1.0
# 75%       0.000000         1.0
# max       1.000000         1.0

# %%
df.groupby('model_name').mean()
# Out:
#                   upscale_time    psnr_sr   psnr_bic  frangi_acc_sr  \
# model_name
# l1                    0.029626  33.430931  33.227886      98.090814
# perceptual            0.003045  32.657150  33.227886      98.105922
# perceptual_pool4      0.003008  32.193472  33.227886      97.996984
# wgan                  0.003193  33.016636  33.227886      98.026988
#
#                   frangi_acc_bic  segmentation_acc_hr  segmentation_acc_sr  \
# model_name
# l1                     97.554522             94.25744            94.138835
# perceptual             97.554522             94.25744            94.270199
# perceptual_pool4       97.554522             94.25744            94.211935
# wgan                   97.554522             94.25744            94.168293
#
#                   segmentation_acc_bic  better_psnr  better_acc
# model_name
# l1                           93.691493         0.75         1.0
# perceptual                   93.691493         0.00         1.0
# perceptual_pool4             93.691493         0.00         1.0
# wgan                         93.691493         0.15         1.0
